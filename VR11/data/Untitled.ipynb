# %%
import pandas as pd
import csv

# %%
data = pd.read_csv('CityAQI.csv',encoding="gbk")

# %%
data.head()
# Out:
#    timeid   城市编码           检测时间  AQI  SO2  NO2  PM10     CO   O3  PM25 城市名  \
# 0       1  City1  2019/9/1 0:00  102   10   26    85  0.906  102    76  南昌
# 1       2  City1  2019/9/1 1:00   97   10   28   102  0.884  101    72  南昌
# 2       3  City1  2019/9/1 2:00   94    9   25    87  0.858   98    70  南昌
# 3       4  City1  2019/9/1 3:00   78   10   26    68  0.745   86    57  南昌
# 4       5  City1  2019/9/1 4:00   69   10   25    65  0.690   72    50  南昌
#
#            jd         wd  cityid  dayid  hourid     y  m  d        h
# 0  115.864589  28.689455       1      1       0  2019  9  1  0:00:00
# 1  115.864589  28.689455       1      1       1  2019  9  1  1:00:00
# 2  115.864589  28.689455       1      1       2  2019  9  1  2:00:00
# 3  115.864589  28.689455       1      1       3  2019  9  1  3:00:00
# 4  115.864589  28.689455       1      1       4  2019  9  1  4:00:00

# %%
print("AQI: " , data["AQI"].min() , "~" , data["AQI"].max() )
print("SO2: " , data["SO2"].min() , "~" , data["SO2"].max() )
print("NO2: " , data["NO2"].min() , "~" , data["NO2"].max() )
print("PM10: " , data["PM10"].min() , "~" , data["PM10"].max() )
print("CO: " , data["CO"].min() , "~" , data["CO"].max() )
print("O3: " , data["O3"].min() , "~" , data["O3"].max() )
print("PM25: " , data["PM25"].min() , "~" , data["PM25"].max() )
# Out:
# AQI:  0 ~ 250
# SO2:  0 ~ 385
# NO2:  0 ~ 161
# PM10:  0 ~ 200
# CO:  0.0 ~ 9.373
# O3:  0 ~ 262
# PM25:  0 ~ 200
