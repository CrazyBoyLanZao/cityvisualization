# %%
import pandas as pd

# %%
data = pd.read_csv('2019年9月.csv')
data.head()
# Out:
#      日期  类型 城市名  id  AQI  PM2.5  PM10  SO2  NO2    CO   O3 等级   排名
# 0  9月1日   1  南昌   1   46     28    47    7   19  0.60   89  优  246
# 1  9月1日   1  赣州   2   49     32    50   14   10  1.07  109  优  269
# 2  9月1日   1  宜春   3   21     10    21    6    9  0.58   17  优   13
# 3  9月1日   1  吉安   4   57     32    64   17   14  0.73  103  良  312
# 4  9月1日   1  上饶   5   36     22    35    2   10  0.63   72  优  156

# %%
data.groupby([data['城市名']]).mean()
# Out:
#       类型    id        AQI      PM2.5       PM10        SO2        NO2  \
# 城市名
# 上饶   1.0   5.0  55.966667  30.800000  59.066667  10.066667  19.866667
# 九江   1.0   7.0  61.833333  36.500000  58.933333  10.700000  22.066667
# 南昌   1.0   1.0  56.300000  29.733333  63.033333   7.800000  24.533333
# 吉安   1.0   4.0  61.800000  34.100000  69.100000  17.600000  18.333333
# 宜春   1.0   3.0  20.866667  10.200000  17.833333   6.300000   8.900000
# 抚州   1.0   6.0  56.233333  33.000000  58.466667   8.666667  13.500000
# 新余   1.0  10.0  57.266667  32.800000  63.600000  17.766667  18.100000
# 景德镇  1.0   8.0  46.766667  25.466667  50.000000   8.766667  16.733333
# 萍乡   1.0   9.0  62.500000  31.466667  68.800000  21.066667  27.166667
# 赣州   1.0   2.0  54.866667  31.866667  55.200000  14.233333  16.533333
# 鹰潭   1.0  11.0  60.966667  37.700000  55.866667  18.100000  20.533333
#
#            CO          O3          排名
# 城市名
# 上饶   0.559000  102.133333  237.500000
# ...

# %%
data.round({'AQI':2,'PM2.5':2,'PM10':2,'SO2':2,'NO2':2,'CO':2,'O3':2,'排名':0})
# Out:
#   File "<ipython-input-8-8d06f10fecaf>", line 1
#     data.round({'AQI':2,'PM2.5':2,'PM10':2,'SO2':2,'NO2':2,'CO':2,'O3':2,'排名'})
#                                                                              ^
# SyntaxError: invalid syntax
